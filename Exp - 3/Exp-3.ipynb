# %% [markdown]
# #  Experiment-3: Stemming, Lemmatization and Regular Expression

# %% [markdown]
# ## Experiment 3.1:  Write a Python program to perform  Write a Python program to perform stemming using the Porter Stemmer. Apply stemming to the following words. Display the original words and their stems.

# %%
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/anirvanranjan/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/anirvanranjan/nltk_data...
# True

# %%
ps = PorterStemmer()
words_1 = ["playing", "played", "plays", "studies", "studying", "connected", "connection", "computers"]

# %%
for word in words_1:
    print(ps.stem(word))
# Out:
# play
# play
# play
# studi
# studi
# connect
# connect
# comput

# %%
for word in words_1:
    lenn = len(word)
    print(f"The Length of the og word: {lenn}")
    ps_word = ps.stem(word)
    print(f"The Porter Stemmer version of the og word |{ps_word}| and it's length {len(ps_word)}")
    print(f"The length disparity {lenn - len(ps_word)}")
# Out:
# The Length of the og word: 7
# The Porter Stemmer version of the og word |play| and it's length 4
# The length disparity 3
# The Length of the og word: 6
# The Porter Stemmer version of the og word |play| and it's length 4
# The length disparity 2
# The Length of the og word: 5
# The Porter Stemmer version of the og word |play| and it's length 4
# The length disparity 1
# The Length of the og word: 7
# The Porter Stemmer version of the og word |studi| and it's length 5
# The length disparity 2
# The Length of the og word: 8
# The Porter Stemmer version of the og word |studi| and it's length 5
# The length disparity 3
# The Length of the og word: 9
# The Porter Stemmer version of the og word |connect| and it's length 7
# The length disparity 2
# The Length of the og word: 10
# The Porter Stemmer version of the og word |connect| and it's length 7
# The length disparity 3
# The Length of the og word: 9
# The Porter Stemmer version of the og word |comput| and it's length 6
# ...

# %% [markdown]
# ## Experiment 3.2:  Write a Python program to perform lemmatization on a given input words:

# %%
words_2 = ["cats", "dogs", "running", "runs", "ran", "studies", "studying", "better", "children", "mice", "went", "ate", "leaves", "caring"]

# %%
lemmatizer = WordNetLemmatizer()

for word in words_2:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# cats -> cat
# dogs -> dog
# running -> running
# runs -> run
# ran -> ran
# studies -> study
# studying -> studying
# better -> better
# children -> child
# mice -> mouse
# went -> went
# ate -> ate
# leaves -> leaf
# caring -> caring

# %%
for word in words_2:
    lenn = len(word)
    print(f"The Length of the og word: {lenn}")
    lm_word = lemmatizer.lemmatize(word)
    print(f"The Lemmatized version of the og word |{lm_word}| and it's length {len(lm_word)}")
    print(f"The length disparity {lenn - len(lm_word)}")
# Out:
# The Length of the og word: 4
# The Lemmatized version of the og word |cat| and it's length 3
# The length disparity 1
# The Length of the og word: 4
# The Lemmatized version of the og word |dog| and it's length 3
# The length disparity 1
# The Length of the og word: 7
# The Lemmatized version of the og word |running| and it's length 7
# The length disparity 0
# The Length of the og word: 4
# The Lemmatized version of the og word |run| and it's length 3
# The length disparity 1
# The Length of the og word: 3
# The Lemmatized version of the og word |ran| and it's length 3
# The length disparity 0
# The Length of the og word: 7
# The Lemmatized version of the og word |study| and it's length 5
# The length disparity 2
# The Length of the og word: 8
# The Lemmatized version of the og word |studying| and it's length 8
# The length disparity 0
# The Length of the og word: 6
# The Lemmatized version of the og word |better| and it's length 6
# The length disparity 0
# ...

# %% [markdown]
# ## Experiment 3.3: Write a Python program using Regular Expressions (Regex) to extract and process the following information from a text:
# Email addresses, URLs, Mobile numbers, Hashtags, Mentions

# %%
import re

text = """Welcome to the Natural Language Processing workshop! For more information, visit
https://www.nlpworkshop.com or www.python.org. You can contact the coordinator at
nlpworkshop@gmail.com or support@python.org. For registration, call +91-9876543210 or
9123456789. Follow us on social media @NLPWorkshop and @PythonLearner. Share your
experience using #NLP, #Python, and #MachineLearning. You can also visit
https://github.com/NLPWorkshop for the latest updates."""

emails = re.findall(r'[\w.+-]+@[\w.-]+\.\w+', text)
urls = re.findall(r'http://[\w./-]+\b|https://[\w./-]+\b|www\.[\w./-]+\b', text)
mobiles = re.findall(r'\+91-[6-9]\d{9}|[6-9]\d{9}', text)
hashtags = re.findall(r'#\w+', text)
mentions = re.findall(r'\B@\w+', text)

print("Email addresses:", emails)
print("URLs:", urls)
print("Mobile numbers:", mobiles)
print("Hashtags:", hashtags)
print("Mentions:", mentions)
# Out:
# Email addresses: ['nlpworkshop@gmail.com', 'support@python.org']
# URLs: ['https://www.nlpworkshop.com', 'www.python.org', 'https://github.com/NLPWorkshop']
# Mobile numbers: ['+91-9876543210', '9123456789']
# Hashtags: ['#NLP', '#Python', '#MachineLearning']
# Mentions: ['@NLPWorkshop', '@PythonLearner']
